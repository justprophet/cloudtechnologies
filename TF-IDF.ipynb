# %% [markdown]
# Akash Bhargava
# 18210613
# akash.bhargava2@mail.dcu.ie

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Proph3t\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
import math
from textblob import TextBlob as tb
import sys
import pandas as pd

# %%
def tf(word, blob):
    return blob.words.count(word) / len(blob.words)

# %%
def n_containing(word, bloblist):
    return sum(1 for blob in bloblist if word in blob.words)

# %%
def idf(word, bloblist):
    return math.log(len(bloblist) / (1 + n_containing(word, bloblist)))

# %%
def tfidf(word, blob, bloblist):
    return tf(word, blob) * idf(word, bloblist)

# %%
df= pd.read_csv('C:/Users/Proph3t/Desktop/MyDA/Semester 2/Cloud Technologies/Lab/Data/Data.csv', engine='python', error_bad_lines=False)
# Out:
# Skipping line 50001: ',' expected after '"'
# Skipping line 100001: ',' expected after '"'
# Skipping line 150001: ',' expected after '"'
# Skipping line 200001: ',' expected after '"'

# %%
body= df.iloc[:,8]
Id= df.iloc[:,0] 

rem= ['<code>','<pre>','</code>','</pre>','<strong>','</strong>','<em>','</em>','<p>','/p']
bloblist= []

for i in range(10000):
    str= body[i]
    for i in range(10):
        str= str.replace(rem[i],'')
    strblob= tb(str)
    bloblist.append(strblob)

for j in range(100):
    bloblist= []
    str= body[j]
    for i in range(10):
        str= str.replace(rem[i],'')
    strblob= tb(str)
    bloblist.append(strblob)

    #bloblist = [document1] #, document2, document3]

    for i, blob in enumerate(bloblist):
        print("Top words for user id {}".format(Id[i]))
        scores = {word: tfidf(word, blob, bloblist) for word in blob.words}
        sorted_words = sorted(scores.items(), key=lambda x: x[1], reverse=True)
        #print(sorted_words)
        for word, score in sorted_words[:10]:
            print("\tWord: {}, TF-IDF: {}".format(word, round(score, 5)))
# Out:
# Top words for user id 12051
# 	Word: a, TF-IDF: -0.00825
# 	Word: and, TF-IDF: -0.00825
# 	Word: inherited, TF-IDF: -0.00825
# 	Word: how, TF-IDF: -0.00825
# 	Word: that, TF-IDF: -0.00825
# 	Word: For, TF-IDF: -0.00825
# 	Word: example, TF-IDF: -0.00825
# 	Word: like, TF-IDF: -0.00825
# 	Word: public, TF-IDF: -0.00825
# 	Word: extraInfo, TF-IDF: -0.00825
# Top words for user id 12051
# 	Word: thus, TF-IDF: -0.00797
# 	Word: far, TF-IDF: -0.00797
# 	Word: avoided, TF-IDF: -0.00797
# 	Word: the, TF-IDF: -0.00797
# 	Word: nightmare, TF-IDF: -0.00797
# 	Word: is, TF-IDF: -0.00797
# 	Word: multi-threaded, TF-IDF: -0.00797
# 	Word: since, TF-IDF: -0.00797
# 	Word: too, TF-IDF: -0.00797
# 	Word: much, TF-IDF: -0.00797
# Top words for user id 12051
# 	Word: How, TF-IDF: -0.04077
# 	Word: do, TF-IDF: -0.04077
# 	Word: you, TF-IDF: -0.04077
# 	Word: scan, TF-IDF: -0.04077
# 	Word: a, TF-IDF: -0.04077
# 	Word: directory, TF-IDF: -0.04077
# 	Word: for, TF-IDF: -0.04077
# 	Word: folders, TF-IDF: -0.04077
# 	Word: and, TF-IDF: -0.04077
# 	Word: files, TF-IDF: -0.04077
# Top words for user id 12051
# 	Word: 'm, TF-IDF: -0.01475
# 	Word: trying, TF-IDF: -0.01475
# 	Word: using, TF-IDF: -0.01475
# 	Word: C, TF-IDF: -0.01475
# 	Word: Any, TF-IDF: -0.01475
# 	Word: tips, TF-IDF: -0.01475
# 	Word: on, TF-IDF: -0.01475
# 	Word: what, TF-IDF: -0.01475
# 	Word: is, TF-IDF: -0.01475
# 	Word: best, TF-IDF: -0.01475
# Top words for user id 12051
# 	Word: there, TF-IDF: -0.01475
# 	Word: simple, TF-IDF: -0.01475
# 	Word: way, TF-IDF: -0.01475
# 	Word: in, TF-IDF: -0.01475
# 	Word: Perl, TF-IDF: -0.01475
# 	Word: will, TF-IDF: -0.01475
# 	Word: allow, TF-IDF: -0.01475
# 	Word: me, TF-IDF: -0.01475
# 	Word: to, TF-IDF: -0.01475
# 	Word: determine, TF-IDF: -0.01475
# Top words for user id 12051
# 	Word: recently, TF-IDF: -0.00559
# 	Word: inherited, TF-IDF: -0.00559
# 	Word: large, TF-IDF: -0.00559
# 	Word: software, TF-IDF: -0.00559
# 	Word: written, TF-IDF: -0.00559
# 	Word: Java, TF-IDF: -0.00559
# 	Word: last, TF-IDF: -0.00559
# 	Word: developer, TF-IDF: -0.00559
# 	Word: used, TF-IDF: -0.00559
# 	Word: so, TF-IDF: -0.00559
# Top words for user id 12051
# 	Word: What, TF-IDF: -0.02773
# 	Word: is, TF-IDF: -0.02773
# 	Word: simplest, TF-IDF: -0.02773
# 	Word: SQL, TF-IDF: -0.02773
# 	Word: query, TF-IDF: -0.02773
# 	Word: to, TF-IDF: -0.02773
# 	Word: find, TF-IDF: -0.02773
# 	Word: second, TF-IDF: -0.02773
# 	Word: largest, TF-IDF: -0.02773
# 	Word: integer, TF-IDF: -0.02773
# Top words for user id 12051
# 	Word: following, TF-IDF: -0.00737
# 	Word: PHP, TF-IDF: -0.00737
# 	Word: code, TF-IDF: -0.00737
# 	Word: snippet, TF-IDF: -0.00737
# 	Word: uses, TF-IDF: -0.00737
# 	Word: GD, TF-IDF: -0.00737
# 	Word: resize, TF-IDF: -0.00737
# 	Word: browser-uploaded, TF-IDF: -0.00737
# 	Word: PNG, TF-IDF: -0.00737
# 	Word: 128x128, TF-IDF: -0.00737
# Top words for user id 12051
# 	Word: Instead, TF-IDF: -0.01777
# 	Word: relying, TF-IDF: -0.01777
# 	Word: host, TF-IDF: -0.01777
# 	Word: send, TF-IDF: -0.01777
# 	Word: was, TF-IDF: -0.01777
# 	Word: thinking, TF-IDF: -0.01777
# 	Word: sending, TF-IDF: -0.01777
# 	Word: messages, TF-IDF: -0.01777
# 	Word: using, TF-IDF: -0.01777
# 	Word: Gmail, TF-IDF: -0.01777
# Top words for user id 12051
# 	Word: joys, TF-IDF: -0.00375
# 	Word: working, TF-IDF: -0.00375
# 	Word: government, TF-IDF: -0.00375
# 	Word: healthcare, TF-IDF: -0.00375
# 	Word: agency, TF-IDF: -0.00375
# 	Word: having, TF-IDF: -0.00375
# 	Word: deal, TF-IDF: -0.00375
# 	Word: paranoia, TF-IDF: -0.00375
# 	Word: dealing, TF-IDF: -0.00375
# 	Word: PHI, TF-IDF: -0.00375
# Top words for user id 12051
# 	Word: Can, TF-IDF: -0.0099
# 	Word: anyone, TF-IDF: -0.0099
# 	Word: tell, TF-IDF: -0.0099
# 	Word: me, TF-IDF: -0.0099
# 	Word: if, TF-IDF: -0.0099
# 	Word: there, TF-IDF: -0.0099
# 	Word: is, TF-IDF: -0.0099
# 	Word: way, TF-IDF: -0.0099
# 	Word: with, TF-IDF: -0.0099
# 	Word: generics, TF-IDF: -0.0099
# Top words for user id 12051
# 	Word: How, TF-IDF: -0.0066
# 	Word: do, TF-IDF: -0.0066
# 	Word: get, TF-IDF: -0.0066
# 	Word: C, TF-IDF: -0.0066
# 	Word: mm/dd/yyyy, TF-IDF: -0.0066
# 	Word: format, TF-IDF: -0.0066
# 	Word: need, TF-IDF: -0.0066
# 	Word: set, TF-IDF: -0.0066
# 	Word: string, TF-IDF: -0.0066
# 	Word: variable, TF-IDF: -0.0066
# Top words for user id 12051
# 	Word: Today, TF-IDF: -0.00475
# 	Word: learn, TF-IDF: -0.00475
# 	Word: more, TF-IDF: -0.00475
# 	Word: about, TF-IDF: -0.00475
# 	Word: Google, TF-IDF: -0.00475
# 	Word: Starter, TF-IDF: -0.00475
# 	Word: Kit, TF-IDF: -0.00475
# 	Word: followed, TF-IDF: -0.00475
# 	Word: href, TF-IDF: -0.00475
# 	Word: https, TF-IDF: -0.00475
# Top words for user id 12051
# 	Word: trying, TF-IDF: -0.00555
# 	Word: add, TF-IDF: -0.00555
# 	Word: custom, TF-IDF: -0.00555
# 	Word: troubles, TF-IDF: -0.00555
# 	Word: know, TF-IDF: -0.00555
# 	Word: is, TF-IDF: -0.00555
# 	Word: n't, TF-IDF: -0.00555
# 	Word: right, TF-IDF: -0.00555
# 	Word: run, TF-IDF: -0.00555
# 	Word: creates, TF-IDF: -0.00555
# Top words for user id 12051
# 	Word: Using, TF-IDF: -0.00797
# 	Word: was, TF-IDF: -0.00797
# 	Word: trying, TF-IDF: -0.00797
# 	Word: develop, TF-IDF: -0.00797
# 	Word: following, TF-IDF: -0.00797
# 	Word: two, TF-IDF: -0.00797
# 	Word: way, TF-IDF: -0.00797
# 	Word: am, TF-IDF: -0.00797
# 	Word: it, TF-IDF: -0.00797
# 	Word: may, TF-IDF: -0.00797
# Top words for user id 12051
# 	Word: installed, TF-IDF: -0.02039
# 	Word: ALL, TF-IDF: -0.02039
# 	Word: Extra, TF-IDF: -0.02039
# 	Word: SDK, TF-IDF: -0.02039
# 	Word: 21-22, TF-IDF: -0.02039
# 	Word: including, TF-IDF: -0.02039
# 	Word: compileSdkVersion, TF-IDF: -0.02039
# 	Word: buildToolsVersion, TF-IDF: -0.02039
# 	Word: '22.0.1, TF-IDF: -0.02039
# 	Word: 21.1.2, TF-IDF: -0.02039
# Top words for user id 12051
# 	Word: do, TF-IDF: -0.0105
# 	Word: catalog, TF-IDF: -0.0105
# 	Word: using, TF-IDF: -0.0105
# 	Word: Bootstrap, TF-IDF: -0.0105
# 	Word: 3, TF-IDF: -0.0105
# 	Word: When, TF-IDF: -0.0105
# 	Word: displayed, TF-IDF: -0.0105
# 	Word: on, TF-IDF: -0.0105
# 	Word: tablets, TF-IDF: -0.0105
# 	Word: product, TF-IDF: -0.0105
# Top words for user id 12051
# 	Word: seem, TF-IDF: -0.02567
# 	Word: be, TF-IDF: -0.02567
# 	Word: many, TF-IDF: -0.02567
# 	Word: ways, TF-IDF: -0.02567
# 	Word: define, TF-IDF: -0.02567
# 	Word: href, TF-IDF: -0.02567
# 	Word: http, TF-IDF: -0.02567
# 	Word: en.wikipedia.org/wiki/Singleton_pattern, TF-IDF: -0.02567
# 	Word: rel, TF-IDF: -0.02567
# 	Word: noreferrer, TF-IDF: -0.02567
# Top words for user id 12051
# 	Word: complete, TF-IDF: -0.00573
# 	Word: would, TF-IDF: -0.00573
# 	Word: like, TF-IDF: -0.00573
# 	Word: object, TF-IDF: -0.00573
# 	Word: Google, TF-IDF: -0.00573
# 	Word: turns, TF-IDF: -0.00573
# 	Word: up, TF-IDF: -0.00573
# 	Word: all, TF-IDF: -0.00573
# 	Word: sorts, TF-IDF: -0.00573
# 	Word: garbage, TF-IDF: -0.00573
# Top words for user id 12051
# 	Word: How, TF-IDF: -0.06931
# 	Word: can, TF-IDF: -0.06931
# 	Word: I, TF-IDF: -0.06931
# 	Word: permanently, TF-IDF: -0.06931
# 	Word: enable, TF-IDF: -0.06931
# 	Word: line, TF-IDF: -0.06931
# 	Word: numbers, TF-IDF: -0.06931
# 	Word: in, TF-IDF: -0.06931
# 	Word: IntelliJ, TF-IDF: -0.06931
# 	Word: IDEA, TF-IDF: -0.06931
# Top words for user id 12051
# 	Word: Is, TF-IDF: -0.08664
# 	Word: there, TF-IDF: -0.08664
# 	Word: a, TF-IDF: -0.08664
# 	Word: function, TF-IDF: -0.08664
# 	Word: like, TF-IDF: -0.08664
# 	Word: document.getElementById, TF-IDF: -0.08664
# 	Word: FirstDiv, TF-IDF: -0.08664
# 	Word: clear, TF-IDF: -0.08664
# Top words for user id 12051
# 	Word: web, TF-IDF: -0.0051
# 	Word: application, TF-IDF: -0.0051
# 	Word: page, TF-IDF: -0.0051
# 	Word: contains, TF-IDF: -0.0051
# 	Word: has, TF-IDF: -0.0051
# 	Word: auto-width, TF-IDF: -0.0051
# 	Word: depending, TF-IDF: -0.0051
# 	Word: on, TF-IDF: -0.0051
# 	Word: width, TF-IDF: -0.0051
# 	Word: window, TF-IDF: -0.0051
# Top words for user id 12051
# 	Word: Whilst, TF-IDF: -0.04077
# 	Word: starting, TF-IDF: -0.04077
# 	Word: to, TF-IDF: -0.04077
# 	Word: learn, TF-IDF: -0.04077
# 	Word: lisp, TF-IDF: -0.04077
# 	Word: I, TF-IDF: -0.04077
# 	Word: 've, TF-IDF: -0.04077
# 	Word: come, TF-IDF: -0.04077
# 	Word: across, TF-IDF: -0.04077
# 	Word: the, TF-IDF: -0.04077
# Top words for user id 12051
# 	Word: would, TF-IDF: -0.01444
# 	Word: you, TF-IDF: -0.01444
# 	Word: go, TF-IDF: -0.01444
# 	Word: about, TF-IDF: -0.01444
# 	Word: finding, TF-IDF: -0.01444
# 	Word: memory, TF-IDF: -0.01444
# 	Word: being, TF-IDF: -0.01444
# 	Word: know, TF-IDF: -0.01444
# 	Word: it, TF-IDF: -0.01444
# 	Word: possible, TF-IDF: -0.01444
# Top words for user id 12051
# 	Word: Given, TF-IDF: -0.0068
# 	Word: some, TF-IDF: -0.0068
# 	Word: e.g, TF-IDF: -0.0068
# 	Word: HKEY_LOCAL_MACHINE\blah\blah\blah\foo, TF-IDF: -0.0068
# 	Word: how, TF-IDF: -0.0068
# 	Word: Safely, TF-IDF: -0.0068
# 	Word: determine, TF-IDF: -0.0068
# 	Word: that, TF-IDF: -0.0068
# 	Word: such, TF-IDF: -0.0068
# 	Word: a, TF-IDF: -0.0068
# Top words for user id 12051
# 	Word: I, TF-IDF: -0.03466
# 	Word: want, TF-IDF: -0.03466
# 	Word: apply, TF-IDF: -0.03466
# 	Word: XSLT, TF-IDF: -0.03466
# 	Word: Stylesheet, TF-IDF: -0.03466
# 	Word: XML, TF-IDF: -0.03466
# 	Word: Document, TF-IDF: -0.03466
# 	Word: using, TF-IDF: -0.03466
# 	Word: C, TF-IDF: -0.03466
# 	Word: and, TF-IDF: -0.03466
# Top words for user id 12051
# 	Word: am, TF-IDF: -0.03851
# 	Word: getting, TF-IDF: -0.03851
# 	Word: a, TF-IDF: -0.03851
# 	Word: NoClassDefFoundError, TF-IDF: -0.03851
# 	Word: when, TF-IDF: -0.03851
# 	Word: run, TF-IDF: -0.03851
# 	Word: my, TF-IDF: -0.03851
# 	Word: Java, TF-IDF: -0.03851
# 	Word: application, TF-IDF: -0.03851
# 	Word: What, TF-IDF: -0.03851
# Top words for user id 12051
# 	Word: Given, TF-IDF: -0.01216
# 	Word: Python, TF-IDF: -0.01216
# 	Word: any, TF-IDF: -0.01216
# 	Word: kind, TF-IDF: -0.01216
# 	Word: get, TF-IDF: -0.01216
# 	Word: list, TF-IDF: -0.01216
# 	Word: all, TF-IDF: -0.01216
# 	Word: methods, TF-IDF: -0.01216
# 	Word: that, TF-IDF: -0.01216
# 	Word: Or, TF-IDF: -0.01216
# Top words for user id 12051
# 	Word: When, TF-IDF: -0.01612
# 	Word: writing, TF-IDF: -0.01612
# 	Word: multi-threaded, TF-IDF: -0.01612
# 	Word: applications, TF-IDF: -0.01612
# 	Word: one, TF-IDF: -0.01612
# 	Word: of, TF-IDF: -0.01612
# 	Word: most, TF-IDF: -0.01612
# 	Word: common, TF-IDF: -0.01612
# 	Word: problems, TF-IDF: -0.01612
# 	Word: experienced, TF-IDF: -0.01612
# Top words for user id 12051
# 	Word: 'm, TF-IDF: -0.03014
# 	Word: new, TF-IDF: -0.03014
# 	Word: SVN, TF-IDF: -0.03014
# 	Word: and, TF-IDF: -0.03014
# 	Word: 'd, TF-IDF: -0.03014
# 	Word: like, TF-IDF: -0.03014
# 	Word: know, TF-IDF: -0.03014
# 	Word: what, TF-IDF: -0.03014
# 	Word: methods, TF-IDF: -0.03014
# 	Word: are, TF-IDF: -0.03014
# Top words for user id 12051
# 	Word: am, TF-IDF: -0.009
# 	Word: using, TF-IDF: -0.009
# 	Word: SQL, TF-IDF: -0.009
# 	Word: Server, TF-IDF: -0.009
# 	Word: 2005, TF-IDF: -0.009
# 	Word: with, TF-IDF: -0.009
# 	Word: many, TF-IDF: -0.009
# 	Word: rows, TF-IDF: -0.009
# 	Word: where, TF-IDF: -0.009
# 	Word: it, TF-IDF: -0.009
# Top words for user id 12051
# 	Word: After, TF-IDF: -0.01691
# 	Word: reading, TF-IDF: -0.01691
# 	Word: Jeff, TF-IDF: -0.01691
# 	Word: 's, TF-IDF: -0.01691
# 	Word: blog, TF-IDF: -0.01691
# 	Word: post, TF-IDF: -0.01691
# 	Word: on, TF-IDF: -0.01691
# 	Word: href, TF-IDF: -0.01691
# 	Word: www.codinghorror.com/blog/archives/001167.html, TF-IDF: -0.01691
# 	Word: rel, TF-IDF: -0.01691
# Top words for user id 12051
# 	Word: assume, TF-IDF: -0.02666
# 	Word: n't, TF-IDF: -0.02666
# 	Word: connect, TF-IDF: -0.02666
# 	Word: to, TF-IDF: -0.02666
# 	Word: anything, TF-IDF: -0.02666
# 	Word: other, TF-IDF: -0.02666
# 	Word: than, TF-IDF: -0.02666
# 	Word: the, TF-IDF: -0.02666
# 	Word: satelite, TF-IDF: -0.02666
# 	Word: guess, TF-IDF: -0.02666
# Top words for user id 12051
# 	Word: So, TF-IDF: -0.00788
# 	Word: every, TF-IDF: -0.00788
# 	Word: time, TF-IDF: -0.00788
# 	Word: turn, TF-IDF: -0.00788
# 	Word: owned, TF-IDF: -0.00788
# 	Word: development, TF-IDF: -0.00788
# 	Word: 10, TF-IDF: -0.00788
# 	Word: using, TF-IDF: -0.00788
# 	Word: task, TF-IDF: -0.00788
# 	Word: manager, TF-IDF: -0.00788
# Top words for user id 12051
# 	Word: What, TF-IDF: -0.00619
# 	Word: saw, TF-IDF: -0.00619
# 	Word: lot, TF-IDF: -0.00619
# 	Word: applications, TF-IDF: -0.00619
# 	Word: data, TF-IDF: -0.00619
# 	Word: structures, TF-IDF: -0.00619
# 	Word: courses, TF-IDF: -0.00619
# 	Word: college, TF-IDF: -0.00619
# 	Word: mostly, TF-IDF: -0.00619
# 	Word: got, TF-IDF: -0.00619
# Top words for user id 12051
# 	Word: When, TF-IDF: -0.00233
# 	Word: try, TF-IDF: -0.00233
# 	Word: do, TF-IDF: -0.00233
# 	Word: command, TF-IDF: -0.00233
# 	Word: supply, TF-IDF: -0.00233
# 	Word: and/or, TF-IDF: -0.00233
# 	Word: prompts, TF-IDF: -0.00233
# 	Word: anyways, TF-IDF: -0.00233
# 	Word: always, TF-IDF: -0.00233
# 	Word: will, TF-IDF: -0.00233
# Top words for user id 12051
# 	Word: programming, TF-IDF: -0.0239
# 	Word: concept, TF-IDF: -0.0239
# 	Word: that, TF-IDF: -0.0239
# 	Word: frequently, TF-IDF: -0.0239
# 	Word: used, TF-IDF: -0.0239
# 	Word: solve, TF-IDF: -0.0239
# 	Word: multi-threading, TF-IDF: -0.0239
# 	Word: problems, TF-IDF: -0.0239
# 	Word: My, TF-IDF: -0.0239
# 	Word: question, TF-IDF: -0.0239
# Top words for user id 12051
# 	Word: programming, TF-IDF: -0.0239
# 	Word: concept, TF-IDF: -0.0239
# 	Word: that, TF-IDF: -0.0239
# 	Word: frequently, TF-IDF: -0.0239
# 	Word: used, TF-IDF: -0.0239
# 	Word: solve, TF-IDF: -0.0239
# 	Word: multi-threading, TF-IDF: -0.0239
# 	Word: problems, TF-IDF: -0.0239
# 	Word: My, TF-IDF: -0.0239
# 	Word: question, TF-IDF: -0.0239
# Top words for user id 12051
# 	Word: How, TF-IDF: -0.0099
# 	Word: do, TF-IDF: -0.0099
# 	Word: I, TF-IDF: -0.0099
# 	Word: unit, TF-IDF: -0.0099
# 	Word: using, TF-IDF: -0.0099
# 	Word: xUnit, TF-IDF: -0.0099
# 	Word: class, TF-IDF: -0.0099
# 	Word: has, TF-IDF: -0.0099
# 	Word: methods, TF-IDF: -0.0099
# 	Word: fields, TF-IDF: -0.0099
# Top words for user id 12051
# 	Word: When, TF-IDF: -0.01733
# 	Word: my, TF-IDF: -0.01733
# 	Word: application, TF-IDF: -0.01733
# 	Word: sometimes, TF-IDF: -0.01733
# 	Word: get, TF-IDF: -0.01733
# 	Word: an, TF-IDF: -0.01733
# 	Word: about, TF-IDF: -0.01733
# 	Word: too, TF-IDF: -0.01733
# 	Word: many, TF-IDF: -0.01733
# 	Word: files, TF-IDF: -0.01733
# Top words for user id 12051
# 	Word: looked, TF-IDF: -0.00428
# 	Word: at, TF-IDF: -0.00428
# 	Word: default, TF-IDF: -0.00428
# 	Word: comes, TF-IDF: -0.00428
# 	Word: JDK, TF-IDF: -0.00428
# 	Word: Apache, TF-IDF: -0.00428
# 	Word: compression, TF-IDF: -0.00428
# 	Word: libs, TF-IDF: -0.00428
# 	Word: am, TF-IDF: -0.00428
# 	Word: unhappy, TF-IDF: -0.00428
# Top words for user id 12051
# 	Word: How, TF-IDF: -0.04621
# 	Word: do, TF-IDF: -0.04621
# 	Word: I, TF-IDF: -0.04621
# 	Word: discard, TF-IDF: -0.04621
# 	Word: changes, TF-IDF: -0.04621
# 	Word: my, TF-IDF: -0.04621
# 	Word: working, TF-IDF: -0.04621
# 	Word: copy, TF-IDF: -0.04621
# 	Word: that, TF-IDF: -0.04621
# 	Word: are, TF-IDF: -0.04621
# Top words for user id 12051
# 	Word: legacy, TF-IDF: -0.00381
# 	Word: private, TF-IDF: -0.00381
# 	Word: void, TF-IDF: -0.00381
# 	Word: conexao.State, TF-IDF: -0.00381
# 	Word: ConnectionState.Closed, TF-IDF: -0.00381
# 	Word: conexao.Open, TF-IDF: -0.00381
# 	Word: public, TF-IDF: -0.00381
# 	Word: get_dados_historico_verificacao_email_WEB, TF-IDF: -0.00381
# 	Word: historico_verificacao_email, TF-IDF: -0.00381
# 	Word: ORDER, TF-IDF: -0.00381
# Top words for user id 12051
# 	Word: How, TF-IDF: -0.0165
# 	Word: do, TF-IDF: -0.0165
# 	Word: list, TF-IDF: -0.0165
# 	Word: the, TF-IDF: -0.0165
# 	Word: symbols, TF-IDF: -0.0165
# 	Word: being, TF-IDF: -0.0165
# 	Word: exported, TF-IDF: -0.0165
# 	Word: so, TF-IDF: -0.0165
# 	Word: file, TF-IDF: -0.0165
# 	Word: possible, TF-IDF: -0.0165
# Top words for user id 12051
# 	Word: 'm, TF-IDF: -0.00361
# 	Word: new, TF-IDF: -0.00361
# 	Word: postgres, TF-IDF: -0.00361
# 	Word: info, TF-IDF: -0.00361
# 	Word: systems, TF-IDF: -0.00361
# 	Word: in, TF-IDF: -0.00361
# 	Word: ran, TF-IDF: -0.00361
# 	Word: sql, TF-IDF: -0.00361
# 	Word: script, TF-IDF: -0.00361
# 	Word: cityid, TF-IDF: -0.00361
# Top words for user id 12051
# 	Word: am, TF-IDF: -0.00654
# 	Word: using, TF-IDF: -0.00654
# 	Word: Windows, TF-IDF: -0.00654
# 	Word: two, TF-IDF: -0.00654
# 	Word: monitors, TF-IDF: -0.00654
# 	Word: Some, TF-IDF: -0.00654
# 	Word: my, TF-IDF: -0.00654
# 	Word: primary, TF-IDF: -0.00654
# 	Word: Others, TF-IDF: -0.00654
# 	Word: secondary, TF-IDF: -0.00654
# Top words for user id 12051
# 	Word: there, TF-IDF: -0.0045
# 	Word: a, TF-IDF: -0.0045
# 	Word: way, TF-IDF: -0.0045
# 	Word: for, TF-IDF: -0.0045
# 	Word: current, TF-IDF: -0.0045
# 	Word: resides, TF-IDF: -0.0045
# 	Word: do, TF-IDF: -0.0045
# 	Word: not, TF-IDF: -0.0045
# 	Word: calling, TF-IDF: -0.0045
# 	Word: just, TF-IDF: -0.0045
# Top words for user id 12051
# 	Word: How, TF-IDF: -0.06301
# 	Word: can, TF-IDF: -0.06301
# 	Word: you, TF-IDF: -0.06301
# 	Word: import, TF-IDF: -0.06301
# 	Word: a, TF-IDF: -0.06301
# 	Word: foxpro, TF-IDF: -0.06301
# 	Word: DBF, TF-IDF: -0.06301
# 	Word: file, TF-IDF: -0.06301
# 	Word: in, TF-IDF: -0.06301
# 	Word: SQL, TF-IDF: -0.06301
# Top words for user id 12051
# 	Word: System.IO.Directory.GetFiles, TF-IDF: -0.00555
# 	Word: returns, TF-IDF: -0.00555
# 	Word: string, TF-IDF: -0.00555
# 	Word: What, TF-IDF: -0.00555
# 	Word: default, TF-IDF: -0.00555
# 	Word: returned, TF-IDF: -0.00555
# 	Word: values, TF-IDF: -0.00555
# 	Word: 'm, TF-IDF: -0.00555
# 	Word: assuming, TF-IDF: -0.00555
# 	Word: name, TF-IDF: -0.00555
# Top words for user id 12051
# 	Word: noticed, TF-IDF: -0.01475
# 	Word: that, TF-IDF: -0.01475
# 	Word: 2008, TF-IDF: -0.01475
# 	Word: is, TF-IDF: -0.01475
# 	Word: placing, TF-IDF: -0.01475
# 	Word: square, TF-IDF: -0.01475
# 	Word: around, TF-IDF: -0.01475
# 	Word: column, TF-IDF: -0.01475
# 	Word: names, TF-IDF: -0.01475
# 	Word: in, TF-IDF: -0.01475
# Top words for user id 12051
# 	Word: evaluating, TF-IDF: -0.00587
# 	Word: CherryPy, TF-IDF: -0.00587
# 	Word: for, TF-IDF: -0.00587
# 	Word: project, TF-IDF: -0.00587
# 	Word: 's, TF-IDF: -0.00587
# 	Word: basically, TF-IDF: -0.00587
# 	Word: JavaScript, TF-IDF: -0.00587
# 	Word: front-end, TF-IDF: -0.00587
# 	Word: from, TF-IDF: -0.00587
# 	Word: client-side, TF-IDF: -0.00587
# Top words for user id 12051
# 	Word: 5.1, TF-IDF: -0.00502
# 	Word: on, TF-IDF: -0.00502
# 	Word: Windows, TF-IDF: -0.00502
# 	Word: XP, TF-IDF: -0.00502
# 	Word: Pro, TF-IDF: -0.00502
# 	Word: SP2, TF-IDF: -0.00502
# 	Word: Besides, TF-IDF: -0.00502
# 	Word: VS, TF-IDF: -0.00502
# 	Word: 2008, TF-IDF: -0.00502
# 	Word: Express, TF-IDF: -0.00502
# Top words for user id 12051
# 	Word: having, TF-IDF: -0.01284
# 	Word: trouble, TF-IDF: -0.01284
# 	Word: writing, TF-IDF: -0.01284
# 	Word: matches, TF-IDF: -0.01284
# 	Word: valid, TF-IDF: -0.01284
# 	Word: IPv6, TF-IDF: -0.01284
# 	Word: addresses, TF-IDF: -0.01284
# 	Word: including, TF-IDF: -0.01284
# 	Word: those, TF-IDF: -0.01284
# 	Word: in, TF-IDF: -0.01284
# Top words for user id 12051
# 	Word: For, TF-IDF: -0.04077
# 	Word: example, TF-IDF: -0.04077
# 	Word: passed, TF-IDF: -0.04077
# 	Word: the, TF-IDF: -0.04077
# 	Word: following, TF-IDF: -0.04077
# 	Word: How, TF-IDF: -0.04077
# 	Word: do, TF-IDF: -0.04077
# 	Word: I, TF-IDF: -0.04077
# 	Word: check, TF-IDF: -0.04077
# 	Word: to, TF-IDF: -0.04077
# Top words for user id 12051
# 	Word: best, TF-IDF: -0.00403
# 	Word: way, TF-IDF: -0.00403
# 	Word: of, TF-IDF: -0.00403
# 	Word: since, TF-IDF: -0.00403
# 	Word: time, TF-IDF: -0.00403
# 	Word: it, TF-IDF: -0.00403
# 	Word: was, TF-IDF: -0.00403
# 	Word: branched, TF-IDF: -0.00403
# 	Word: from, TF-IDF: -0.00403
# 	Word: current, TF-IDF: -0.00403
# Top words for user id 12051
# 	Word: I, TF-IDF: -0.01575
# 	Word: hope, TF-IDF: -0.01575
# 	Word: this, TF-IDF: -0.01575
# 	Word: qualifies, TF-IDF: -0.01575
# 	Word: a, TF-IDF: -0.01575
# 	Word: question, TF-IDF: -0.01575
# 	Word: any, TF-IDF: -0.01575
# 	Word: tutorial, TF-IDF: -0.01575
# 	Word: you, TF-IDF: -0.01575
# 	Word: eventually, TF-IDF: -0.01575
# Top words for user id 12051
# 	Word: Migrating, TF-IDF: -0.01824
# 	Word: a, TF-IDF: -0.01824
# 	Word: project, TF-IDF: -0.01824
# 	Word: from, TF-IDF: -0.01824
# 	Word: 1.1, TF-IDF: -0.01824
# 	Word: 2.0, TF-IDF: -0.01824
# 	Word: and, TF-IDF: -0.01824
# 	Word: keep, TF-IDF: -0.01824
# 	Word: hitting, TF-IDF: -0.01824
# 	Word: this, TF-IDF: -0.01824
# Top words for user id 12051
# 	Word: Say, TF-IDF: -0.01691
# 	Word: you, TF-IDF: -0.01691
# 	Word: 've, TF-IDF: -0.01691
# 	Word: got, TF-IDF: -0.01691
# 	Word: a, TF-IDF: -0.01691
# 	Word: credit, TF-IDF: -0.01691
# 	Word: number, TF-IDF: -0.01691
# 	Word: with, TF-IDF: -0.01691
# 	Word: an, TF-IDF: -0.01691
# 	Word: expiration, TF-IDF: -0.01691
# Top words for user id 12051
# 	Word: following, TF-IDF: -0.02666
# 	Word: SQL, TF-IDF: -0.02666
# 	Word: SELECT, TF-IDF: -0.02666
# 	Word: notes, TF-IDF: -0.02666
# 	Word: 'SomeText', TF-IDF: -0.02666
# 	Word: FROM, TF-IDF: -0.02666
# 	Word: NotesTable, TF-IDF: -0.02666
# 	Word: a, TF-IDF: -0.02666
# 	Word: Give, TF-IDF: -0.02666
# 	Word: error, TF-IDF: -0.02666
# Top words for user id 12051
# 	Word: need, TF-IDF: -0.00779
# 	Word: retrieve, TF-IDF: -0.00779
# 	Word: rows, TF-IDF: -0.00779
# 	Word: a, TF-IDF: -0.00779
# 	Word: table, TF-IDF: -0.00779
# 	Word: 2, TF-IDF: -0.00779
# 	Word: columns, TF-IDF: -0.00779
# 	Word: combined, TF-IDF: -0.00779
# 	Word: different, TF-IDF: -0.00779
# 	Word: want, TF-IDF: -0.00779
# Top words for user id 12051
# 	Word: Everything, TF-IDF: -0.01612
# 	Word: is, TF-IDF: -0.01612
# 	Word: OK, TF-IDF: -0.01612
# 	Word: Xcode4.6, TF-IDF: -0.01612
# 	Word: When, TF-IDF: -0.01612
# 	Word: try, TF-IDF: -0.01612
# 	Word: use, TF-IDF: -0.01612
# 	Word: Xcode5, TF-IDF: -0.01612
# 	Word: dp6, TF-IDF: -0.01612
# 	Word: run, TF-IDF: -0.01612
# Top words for user id 12051
# 	Word: What, TF-IDF: -0.04621
# 	Word: are, TF-IDF: -0.04621
# 	Word: the, TF-IDF: -0.04621
# 	Word: available, TF-IDF: -0.04621
# 	Word: libraries, TF-IDF: -0.04621
# 	Word: for, TF-IDF: -0.04621
# 	Word: creating, TF-IDF: -0.04621
# 	Word: pretty, TF-IDF: -0.04621
# 	Word: charts, TF-IDF: -0.04621
# 	Word: and, TF-IDF: -0.04621
# Top words for user id 12051
# 	Word: I, TF-IDF: -0.01066
# 	Word: get, TF-IDF: -0.01066
# 	Word: when, TF-IDF: -0.01066
# 	Word: using, TF-IDF: -0.01066
# 	Word: lt, TF-IDF: -0.01066
# 	Word: line, TF-IDF: -0.01066
# 	Word: column, TF-IDF: -0.01066
# 	Word: severity, TF-IDF: -0.01066
# 	Word: message, TF-IDF: -0.01066
# 	Word: available, TF-IDF: -0.01066
# Top words for user id 12051
# 	Word: 've, TF-IDF: -0.0066
# 	Word: started, TF-IDF: -0.0066
# 	Word: using, TF-IDF: -0.0066
# 	Word: Vim, TF-IDF: -0.0066
# 	Word: develop, TF-IDF: -0.0066
# 	Word: Perl, TF-IDF: -0.0066
# 	Word: scripts, TF-IDF: -0.0066
# 	Word: am, TF-IDF: -0.0066
# 	Word: starting, TF-IDF: -0.0066
# 	Word: find, TF-IDF: -0.0066
# Top words for user id 12051
# 	Word: When, TF-IDF: -0.01083
# 	Word: trying, TF-IDF: -0.01083
# 	Word: connect, TF-IDF: -0.01083
# 	Word: an, TF-IDF: -0.01083
# 	Word: user, TF-IDF: -0.01083
# 	Word: via, TF-IDF: -0.01083
# 	Word: TOAD, TF-IDF: -0.01083
# 	Word: Quest, TF-IDF: -0.01083
# 	Word: Software, TF-IDF: -0.01083
# 	Word: any, TF-IDF: -0.01083
# Top words for user id 12051
# 	Word: Java, TF-IDF: -0.02773
# 	Word: has, TF-IDF: -0.02773
# 	Word: a, TF-IDF: -0.02773
# 	Word: convenient, TF-IDF: -0.02773
# 	Word: split, TF-IDF: -0.02773
# 	Word: method, TF-IDF: -0.02773
# 	Word: str, TF-IDF: -0.02773
# 	Word: The, TF-IDF: -0.02773
# 	Word: quick, TF-IDF: -0.02773
# 	Word: brown, TF-IDF: -0.02773
# Top words for user id 12051
# 	Word: just, TF-IDF: -0.01083
# 	Word: installed, TF-IDF: -0.01083
# 	Word: ca, TF-IDF: -0.01083
# 	Word: n't, TF-IDF: -0.01083
# 	Word: make, TF-IDF: -0.01083
# 	Word: it, TF-IDF: -0.01083
# 	Word: have, TF-IDF: -0.01083
# 	Word: such, TF-IDF: -0.01083
# 	Word: line, TF-IDF: -0.01083
# 	Word: at, TF-IDF: -0.01083
# Top words for user id 12051
# 	Word: Alright, TF-IDF: -0.00715
# 	Word: so, TF-IDF: -0.00715
# 	Word: I, TF-IDF: -0.00715
# 	Word: 'm, TF-IDF: -0.00715
# 	Word: working, TF-IDF: -0.00715
# 	Word: on, TF-IDF: -0.00715
# 	Word: an, TF-IDF: -0.00715
# 	Word: which, TF-IDF: -0.00715
# 	Word: use, TF-IDF: -0.00715
# 	Word: Linux, TF-IDF: -0.00715
# Top words for user id 12051
# 	Word: Sending, TF-IDF: -0.00613
# 	Word: Unix, TF-IDF: -0.00613
# 	Word: command, TF-IDF: -0.00613
# 	Word: TO_ADDR, TF-IDF: -0.00613
# 	Word: results, TF-IDF: -0.00613
# 	Word: in, TF-IDF: -0.00613
# 	Word: an, TF-IDF: -0.00613
# 	Word: email, TF-IDF: -0.00613
# 	Word: USER, TF-IDF: -0.00613
# 	Word: HOSTNAME, TF-IDF: -0.00613
# Top words for user id 12051
# 	Word: What, TF-IDF: -0.03301
# 	Word: is, TF-IDF: -0.03301
# 	Word: difference, TF-IDF: -0.03301
# 	Word: between, TF-IDF: -0.03301
# 	Word: old, TF-IDF: -0.03301
# 	Word: and, TF-IDF: -0.03301
# 	Word: new, TF-IDF: -0.03301
# 	Word: classes, TF-IDF: -0.03301
# 	Word: in, TF-IDF: -0.03301
# 	Word: Python, TF-IDF: -0.03301
# Top words for user id 12051
# 	Word: Alright, TF-IDF: -0.0239
# 	Word: it, TF-IDF: -0.0239
# 	Word: can, TF-IDF: -0.0239
# 	Word: be, TF-IDF: -0.0239
# 	Word: a, TF-IDF: -0.0239
# 	Word: lame, TF-IDF: -0.0239
# 	Word: question, TF-IDF: -0.0239
# 	Word: but, TF-IDF: -0.0239
# 	Word: everybody, TF-IDF: -0.0239
# 	Word: uses, TF-IDF: -0.0239
# Top words for user id 12051
# 	Word: have, TF-IDF: -0.01475
# 	Word: an, TF-IDF: -0.01475
# 	Word: that, TF-IDF: -0.01475
# 	Word: 'd, TF-IDF: -0.01475
# 	Word: like, TF-IDF: -0.01475
# 	Word: return, TF-IDF: -0.01475
# 	Word: copy, TF-IDF: -0.01475
# 	Word: of, TF-IDF: -0.01475
# 	Word: which, TF-IDF: -0.01475
# 	Word: following, TF-IDF: -0.01475
# Top words for user id 12051
# 	Word: Is, TF-IDF: -0.04077
# 	Word: it, TF-IDF: -0.04077
# 	Word: possible, TF-IDF: -0.04077
# 	Word: to, TF-IDF: -0.04077
# 	Word: change, TF-IDF: -0.04077
# 	Word: hostname, TF-IDF: -0.04077
# 	Word: in, TF-IDF: -0.04077
# 	Word: Windows, TF-IDF: -0.04077
# 	Word: 2003, TF-IDF: -0.04077
# 	Word: from, TF-IDF: -0.04077
# Top words for user id 12051
# 	Word: When, TF-IDF: -0.00722
# 	Word: user, TF-IDF: -0.00722
# 	Word: on, TF-IDF: -0.00722
# 	Word: our, TF-IDF: -0.00722
# 	Word: site, TF-IDF: -0.00722
# 	Word: loses, TF-IDF: -0.00722
# 	Word: his, TF-IDF: -0.00722
# 	Word: heads, TF-IDF: -0.00722
# 	Word: off, TF-IDF: -0.00722
# 	Word: Lost, TF-IDF: -0.00722
# Top words for user id 12051
# 	Word: need, TF-IDF: -0.0165
# 	Word: quickly, TF-IDF: -0.0165
# 	Word: forcibly, TF-IDF: -0.0165
# 	Word: kill, TF-IDF: -0.0165
# 	Word: off, TF-IDF: -0.0165
# 	Word: all, TF-IDF: -0.0165
# 	Word: external, TF-IDF: -0.0165
# 	Word: sessions, TF-IDF: -0.0165
# 	Word: connecting, TF-IDF: -0.0165
# 	Word: my, TF-IDF: -0.0165
# Top words for user id 12051
# 	Word: As, TF-IDF: -0.00745
# 	Word: stands, TF-IDF: -0.00745
# 	Word: now, TF-IDF: -0.00745
# 	Word: 'm, TF-IDF: -0.00745
# 	Word: Java, TF-IDF: -0.00745
# 	Word: C, TF-IDF: -0.00745
# 	Word: developer, TF-IDF: -0.00745
# 	Word: look, TF-IDF: -0.00745
# 	Word: at, TF-IDF: -0.00745
# 	Word: Ruby, TF-IDF: -0.00745
# Top words for user id 12051
# 	Word: make, TF-IDF: -0.00492
# 	Word: JavaScript, TF-IDF: -0.00492
# 	Word: with, TF-IDF: -0.00492
# 	Word: 'd, TF-IDF: -0.00492
# 	Word: Restaurant.prototype.buy_food, TF-IDF: -0.00492
# 	Word: way, TF-IDF: -0.00492
# 	Word: restaurant.buy_food, TF-IDF: -0.00492
# 	Word: restaurant.use_restroom, TF-IDF: -0.00492
# 	Word: create, TF-IDF: -0.00492
# 	Word: buy_food, TF-IDF: -0.00492
# Top words for user id 12051
# 	Word: one, TF-IDF: -0.01238
# 	Word: has, TF-IDF: -0.01238
# 	Word: me, TF-IDF: -0.01238
# 	Word: kind, TF-IDF: -0.01238
# 	Word: stumped, TF-IDF: -0.01238
# 	Word: want, TF-IDF: -0.01238
# 	Word: make, TF-IDF: -0.01238
# 	Word: all, TF-IDF: -0.01238
# 	Word: my, TF-IDF: -0.01238
# 	Word: content, TF-IDF: -0.01238
# Top words for user id 12051
# 	Word: What, TF-IDF: -0.0165
# 	Word: 's, TF-IDF: -0.0165
# 	Word: simplest, TF-IDF: -0.0165
# 	Word: way, TF-IDF: -0.0165
# 	Word: add, TF-IDF: -0.0165
# 	Word: event, TF-IDF: -0.0165
# 	Word: handler, TF-IDF: -0.0165
# 	Word: that, TF-IDF: -0.0165
# 	Word: return, TF-IDF: -0.0165
# 	Word: x, TF-IDF: -0.0165
# Top words for user id 12051
# 	Word: 'm, TF-IDF: -0.00348
# 	Word: using, TF-IDF: -0.00348
# 	Word: custom-built, TF-IDF: -0.00348
# 	Word: inhouse, TF-IDF: -0.00348
# 	Word: generates, TF-IDF: -0.00348
# 	Word: standard, TF-IDF: -0.00348
# 	Word: reports, TF-IDF: -0.00348
# 	Word: on, TF-IDF: -0.00348
# 	Word: weekly, TF-IDF: -0.00348
# 	Word: basis, TF-IDF: -0.00348
# Top words for user id 12051
# 	Word: What, TF-IDF: -0.04332
# 	Word: is, TF-IDF: -0.04332
# 	Word: difference, TF-IDF: -0.04332
# 	Word: between, TF-IDF: -0.04332
# 	Word: const, TF-IDF: -0.04332
# 	Word: readonly, TF-IDF: -0.04332
# 	Word: do, TF-IDF: -0.04332
# 	Word: you, TF-IDF: -0.04332
# 	Word: use, TF-IDF: -0.04332
# 	Word: one, TF-IDF: -0.04332
# Top words for user id 12051
# 	Word: According, TF-IDF: -0.03466
# 	Word: documentation, TF-IDF: -0.03466
# 	Word: they, TF-IDF: -0.03466
# 	Word: 're, TF-IDF: -0.03466
# 	Word: pretty, TF-IDF: -0.03466
# 	Word: much, TF-IDF: -0.03466
# 	Word: interchangeable, TF-IDF: -0.03466
# 	Word: Is, TF-IDF: -0.03466
# 	Word: there, TF-IDF: -0.03466
# 	Word: a, TF-IDF: -0.03466
# Top words for user id 12051
# 	Word: 'm, TF-IDF: -0.00753
# 	Word: refactoring, TF-IDF: -0.00753
# 	Word: my, TF-IDF: -0.00753
# 	Word: code, TF-IDF: -0.00753
# 	Word: implement, TF-IDF: -0.00753
# 	Word: more, TF-IDF: -0.00753
# 	Word: OOP, TF-IDF: -0.00753
# 	Word: set, TF-IDF: -0.00753
# 	Word: up, TF-IDF: -0.00753
# 	Word: hold, TF-IDF: -0.00753
# Top words for user id 12051
# 	Word: what, TF-IDF: -0.04621
# 	Word: scenarios, TF-IDF: -0.04621
# 	Word: is, TF-IDF: -0.04621
# 	Word: it, TF-IDF: -0.04621
# 	Word: better, TF-IDF: -0.04621
# 	Word: to, TF-IDF: -0.04621
# 	Word: use, TF-IDF: -0.04621
# 	Word: struct, TF-IDF: -0.04621
# 	Word: vs, TF-IDF: -0.04621
# 	Word: class, TF-IDF: -0.04621
# Top words for user id 12051
# 	Word: Does, TF-IDF: -0.01333
# 	Word: any, TF-IDF: -0.01333
# 	Word: one, TF-IDF: -0.01333
# 	Word: know, TF-IDF: -0.01333
# 	Word: how, TF-IDF: -0.01333
# 	Word: get, TF-IDF: -0.01333
# 	Word: of, TF-IDF: -0.01333
# 	Word: local, TF-IDF: -0.01333
# 	Word: machine, TF-IDF: -0.01333
# 	Word: What, TF-IDF: -0.01333
# Top words for user id 12051
# 	Word: following, TF-IDF: -0.00447
# 	Word: sets, TF-IDF: -0.00447
# 	Word: But, TF-IDF: -0.00447
# 	Word: this, TF-IDF: -0.00447
# 	Word: does, TF-IDF: -0.00447
# 	Word: n't, TF-IDF: -0.00447
# 	Word: seem, TF-IDF: -0.00447
# 	Word: work, TF-IDF: -0.00447
# 	Word: How, TF-IDF: -0.00447
# 	Word: do, TF-IDF: -0.00447
# Top words for user id 12051
# 	Word: process, TF-IDF: -0.00648
# 	Word: text, TF-IDF: -0.00648
# 	Word: might, TF-IDF: -0.00648
# 	Word: require, TF-IDF: -0.00648
# 	Word: example, TF-IDF: -0.00648
# 	Word: int, TF-IDF: -0.00648
# 	Word: 0, TF-IDF: -0.00648
# 	Word: if, TF-IDF: -0.00648
# 	Word: that, TF-IDF: -0.00648
# 	Word: But, TF-IDF: -0.00648
# Top words for user id 12051
# 	Word: am, TF-IDF: -0.01238
# 	Word: not, TF-IDF: -0.01238
# 	Word: new, TF-IDF: -0.01238
# 	Word: nix, TF-IDF: -0.01238
# 	Word: however, TF-IDF: -0.01238
# 	Word: lately, TF-IDF: -0.01238
# 	Word: have, TF-IDF: -0.01238
# 	Word: been, TF-IDF: -0.01238
# 	Word: spending, TF-IDF: -0.01238
# 	Word: lot, TF-IDF: -0.01238
# Top words for user id 12051
# 	Word: want, TF-IDF: -0.00976
# 	Word: detect, TF-IDF: -0.00976
# 	Word: if, TF-IDF: -0.00976
# 	Word: numbers, TF-IDF: -0.00976
# 	Word: and, TF-IDF: -0.00976
# 	Word: For, TF-IDF: -0.00976
# 	Word: example, TF-IDF: -0.00976
# 	Word: PncC1KECj4pPVW, TF-IDF: -0.00976
# 	Word: written, TF-IDF: -0.00976
# 	Word: text, TF-IDF: -0.00976
# Top words for user id 12051
# 	Word: long, TF-IDF: -0.01386
# 	Word: line, TF-IDF: -0.01386
# 	Word: code, TF-IDF: -0.01386
# 	Word: that, TF-IDF: -0.01386
# 	Word: want, TF-IDF: -0.01386
# 	Word: to, TF-IDF: -0.01386
# 	Word: break, TF-IDF: -0.01386
# 	Word: up, TF-IDF: -0.01386
# 	Word: among, TF-IDF: -0.01386
# 	Word: multiple, TF-IDF: -0.01386
# Top words for user id 12051
# 	Word: How, TF-IDF: -0.01118
# 	Word: often, TF-IDF: -0.01118
# 	Word: should, TF-IDF: -0.01118
# 	Word: you, TF-IDF: -0.01118
# 	Word: use, TF-IDF: -0.01118
# 	Word: git-gc, TF-IDF: -0.01118
# 	Word: The, TF-IDF: -0.01118
# 	Word: href, TF-IDF: -0.01118
# 	Word: http, TF-IDF: -0.01118
# 	Word: www.kernel.orgub/software/scm/git/docs/git-gc.html, TF-IDF: -0.01118
# Top words for user id 12051
# 	Word: Is, TF-IDF: -0.04951
# 	Word: there, TF-IDF: -0.04951
# 	Word: a, TF-IDF: -0.04951
# 	Word: simple, TF-IDF: -0.04951
# 	Word: method, TF-IDF: -0.04951
# 	Word: of, TF-IDF: -0.04951
# 	Word: parsing, TF-IDF: -0.04951
# 	Word: XML, TF-IDF: -0.04951
# 	Word: files, TF-IDF: -0.04951
# 	Word: in, TF-IDF: -0.04951
# Top words for user id 12051
# 	Word: need, TF-IDF: -0.00398
# 	Word: store, TF-IDF: -0.00398
# 	Word: table, TF-IDF: -0.00398
# 	Word: suggest, TF-IDF: -0.00398
# 	Word: which, TF-IDF: -0.00398
# 	Word: datatype, TF-IDF: -0.00398
# 	Word: Wait, TF-IDF: -0.00398
# 	Word: read, TF-IDF: -0.00398
# 	Word: before, TF-IDF: -0.00398
# 	Word: you, TF-IDF: -0.00398
# Top words for user id 12051
# 	Word: have, TF-IDF: -0.00779
# 	Word: DataSet, TF-IDF: -0.00779
# 	Word: which, TF-IDF: -0.00779
# 	Word: get, TF-IDF: -0.00779
# 	Word: am, TF-IDF: -0.00779
# 	Word: being, TF-IDF: -0.00779
# 	Word: passed, TF-IDF: -0.00779
# 	Word: back, TF-IDF: -0.00779
# 	Word: function, TF-IDF: -0.00779
# 	Word: call, TF-IDF: -0.00779
# Top words for user id 12051
# 	Word: possible, TF-IDF: -0.00555
# 	Word: create, TF-IDF: -0.00555
# 	Word: an, TF-IDF: -0.00555
# 	Word: instance, TF-IDF: -0.00555
# 	Word: generic, TF-IDF: -0.00555
# 	Word: in, TF-IDF: -0.00555
# 	Word: Java, TF-IDF: -0.00555
# 	Word: thinking, TF-IDF: -0.00555
# 	Word: based, TF-IDF: -0.00555
# 	Word: on, TF-IDF: -0.00555
# Top words for user id 12051
# 	Word: Got, TF-IDF: -0.01575
# 	Word: bluescreen, TF-IDF: -0.01575
# 	Word: in, TF-IDF: -0.01575
# 	Word: windows, TF-IDF: -0.01575
# 	Word: while, TF-IDF: -0.01575
# 	Word: cloning, TF-IDF: -0.01575
# 	Word: mercurial, TF-IDF: -0.01575
# 	Word: After, TF-IDF: -0.01575
# 	Word: reboot, TF-IDF: -0.01575
# 	Word: I, TF-IDF: -0.01575
# Top words for user id 12051
# 	Word: What, TF-IDF: -0.06931
# 	Word: 's, TF-IDF: -0.06931
# 	Word: the, TF-IDF: -0.06931
# 	Word: difference, TF-IDF: -0.06931
# 	Word: between, TF-IDF: -0.06931
# 	Word: struct, TF-IDF: -0.06931
# 	Word: and, TF-IDF: -0.06931
# 	Word: class, TF-IDF: -0.06931
# 	Word: in, TF-IDF: -0.06931
# 	Word: NET, TF-IDF: -0.06931
# Top words for user id 12051
# 	Word: use, TF-IDF: -0.01873
# 	Word: to, TF-IDF: -0.01873
# 	Word: perform, TF-IDF: -0.01873
# 	Word: a, TF-IDF: -0.01873
# 	Word: HTTP, TF-IDF: -0.01873
# 	Word: post, TF-IDF: -0.01873
# 	Word: like, TF-IDF: -0.01873
# 	Word: import, TF-IDF: -0.01873
# 	Word: from, TF-IDF: -0.01873
# 	Word: 'axios', TF-IDF: -0.01873
# Top words for user id 12051
# 	Word: Is, TF-IDF: -0.01083
# 	Word: there, TF-IDF: -0.01083
# 	Word: built-in/quick, TF-IDF: -0.01083
# 	Word: way, TF-IDF: -0.01083
# 	Word: keys, TF-IDF: -0.01083
# 	Word: items, TF-IDF: -0.01083
# 	Word: For, TF-IDF: -0.01083
# 	Word: instance, TF-IDF: -0.01083
# 	Word: have, TF-IDF: -0.01083
# 	Word: mydict, TF-IDF: -0.01083
# Top words for user id 12051
# 	Word: sketching, TF-IDF: -0.00325
# 	Word: architecture, TF-IDF: -0.00325
# 	Word: set, TF-IDF: -0.00325
# 	Word: share, TF-IDF: -0.00325
# 	Word: various, TF-IDF: -0.00325
# 	Word: interrelated, TF-IDF: -0.00325
# 	Word: stored, TF-IDF: -0.00325
# 	Word: database, TF-IDF: -0.00325
# 	Word: want, TF-IDF: -0.00325
# 	Word: act, TF-IDF: -0.00325
